# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('data.csv')
data.head()
# Out:
#     Age  Gender  Education  Introversion Score  Sensing Score  Thinking Score  \
# 0  19.0    Male          0             9.47080       7.141434         6.03696
# 1  27.0  Female          0             5.85392       6.160195         0.80552
# 2  21.0  Female          0             7.08615       3.388433         2.66188
# 3  28.0    Male          0             2.01892       4.823624         7.30625
# 4  36.0  Female          1             9.91703       4.755080         5.31469
#
#    Judging Score    Interest Personality
# 0       4.360278     Unknown        ENFP
# 1       4.221421      Sports        ESFP
# 2       5.127320     Unknown        ENFP
# 3       5.986550      Others        INTP
# 4       4.677213  Technology        ENFP

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128061 entries, 0 to 128060
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Age                 128061 non-null  float64
#  1   Gender              128061 non-null  object
#  2   Education           128061 non-null  int64
#  3   Introversion Score  128061 non-null  float64
#  4   Sensing Score       128061 non-null  float64
#  5   Thinking Score      128061 non-null  float64
#  6   Judging Score       128061 non-null  float64
#  7   Interest            128061 non-null  object
#  8   Personality         128061 non-null  object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 8.8+ MB

# %%
data.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Education             0
# Introversion Score    0
# Sensing Score         0
# Thinking Score        0
# Judging Score         0
# Interest              0
# Personality           0
# dtype: int64

# %%
print(data['Gender'].unique())
# Out:
# ['Male' 'Female']

# %%
data['Gender']=data['Gender'].astype(str)

# %%
data.head()
# Out:
#     Age  Gender  Education  Introversion Score  Sensing Score  Thinking Score  \
# 0  19.0    Male          0             9.47080       7.141434         6.03696
# 1  27.0  Female          0             5.85392       6.160195         0.80552
# 2  21.0  Female          0             7.08615       3.388433         2.66188
# 3  28.0    Male          0             2.01892       4.823624         7.30625
# 4  36.0  Female          1             9.91703       4.755080         5.31469
#
#    Judging Score    Interest Personality
# 0       4.360278     Unknown        ENFP
# 1       4.221421      Sports        ESFP
# 2       5.127320     Unknown        ENFP
# 3       5.986550      Others        INTP
# 4       4.677213  Technology        ENFP

# %%
data['Gender']=data['Gender'].map({'Male': 1, 'Female': 0})

# %%
data.head()
# Out:
#     Age  Gender  Education  Introversion Score  Sensing Score  Thinking Score  \
# 0  19.0       1          0             9.47080       7.141434         6.03696
# 1  27.0       0          0             5.85392       6.160195         0.80552
# 2  21.0       0          0             7.08615       3.388433         2.66188
# 3  28.0       1          0             2.01892       4.823624         7.30625
# 4  36.0       0          1             9.91703       4.755080         5.31469
#
#    Judging Score    Interest Personality
# 0       4.360278     Unknown        ENFP
# 1       4.221421      Sports        ESFP
# 2       5.127320     Unknown        ENFP
# 3       5.986550      Others        INTP
# 4       4.677213  Technology        ENFP

# %%
data['Introversion Score'] = data['Introversion Score'].round(0).astype(int)
data['Sensing Score'] = data['Sensing Score'].round(0).astype(int)
data['Thinking Score'] = data['Thinking Score'].round(0).astype(int)
data['Judging Score'] = data['Judging Score'].round(0).astype(int)
data['Age'] = data['Age'].round(0).astype(int)


data.head()
# Out:
#    Age  Gender  Education  Introversion Score  Sensing Score  Thinking Score  \
# 0   19       1          0                   9              7               6
# 1   27       0          0                   6              6               1
# 2   21       0          0                   7              3               3
# 3   28       1          0                   2              5               7
# 4   36       0          1                  10              5               5
#
#    Judging Score  Interest  Personality
# 0              4         0            1
# 1              4         1            5
# 2              5         0            1
# 3              6         4           11
# 4              5         2            1

# %%
print(data['Interest'].unique())
# Out:
# ['Unknown' 'Sports' 'Others' 'Technology' 'Arts']

# %%
data['Interest']=data['Interest'].astype(str)

# %%
data['Interest']=data['Interest'].map({'Unknown': 0, 'Sports': 1,'Technology': 2,'Arts': 3,'Others': 4})

# %%
print(data['Personality'].unique())
# Out:
# ['ENFP' 'ESFP' 'INTP' 'INFP' 'ENFJ' 'ENTP' 'ESTP' 'ISTP' 'INTJ' 'INFJ'
#  'ISFP' 'ENTJ' 'ESFJ' 'ISFJ' 'ISTJ' 'ESTJ']

# %% [markdown]
# ENFP: Inspiring
# ESFP: Entertainer
# INTP: Thinker
# INFP: Idealist
# ENFJ: Charismatic
# ENTP: Innovator
# ESTP: Adventurer
# ISTP: Craftsman
# INTJ: Strategist
# INFJ: Visionary
# ISFP: Artist
# ENTJ: Leader
# ESFJ: Supporter
# ISFJ: Caretaker
# ISTJ: Organizer
# ESTJ: Manager

# %%
from sklearn.preprocessing import LabelEncoder


le = LabelEncoder()


data['Personality'] = le.fit_transform(data['Personality'])

for class_label, numeric_value in zip(le.classes_, range(len(le.classes_))):
    print(f"{class_label} -> {numeric_value}")

print(data)
# Out:
# ENFJ -> 0
# ENFP -> 1
# ENTJ -> 2
# ENTP -> 3
# ESFJ -> 4
# ESFP -> 5
# ESTJ -> 6
# ESTP -> 7
# INFJ -> 8
# INFP -> 9
# INTJ -> 10
# INTP -> 11
# ISFJ -> 12
# ISFP -> 13
# ISTJ -> 14
# ISTP -> 15
#         Age  Gender  Education  Introversion Score  Sensing Score  \
# 0        19       1          0                   9              7
# 1        27       0          0                   6              6
# 2        21       0          0                   7              3
# 3        28       1          0                   2              5
# 4        36       0          1                  10              5
# ...     ...     ...        ...                 ...            ...
# 128056   27       1          0                   5              8
# 128057   19       1          0                   3              3
# 128058   26       0          1                   8              3
# 128059   24       1          0                   9              5
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128061 entries, 0 to 128060
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Age                 128061 non-null  int64
#  1   Gender              128061 non-null  int64
#  2   Education           128061 non-null  int64
#  3   Introversion Score  128061 non-null  int64
#  4   Sensing Score       128061 non-null  int64
#  5   Thinking Score      128061 non-null  int64
#  6   Judging Score       128061 non-null  int64
#  7   Interest            128061 non-null  int64
#  8   Personality         128061 non-null  int64
# dtypes: int64(9)
# memory usage: 8.8 MB

# %%
plt.figure(figsize=(12,10))
cor = data.corr()
sns.heatmap(cor, annot=True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Personality', hue='Gender', data=data, palette='Set2')
plt.xlabel('Personality')
plt.ylabel('gender')
plt.title('Personality vs Gender')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Personality', hue='Education', data=data, palette='Set2')
plt.xlabel('Personality')
plt.ylabel('education')
plt.title('Personality vs education')
plt.show()

# %%
X = data.iloc[:,:-1]
y = data['Personality']

# %%
data.shape
# Out:
# (128061, 9)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %%
print("Train Set: ", X_train.shape, y_train.shape)
print("Test Set: ", X_test.shape, y_test.shape)
# Out:
# Train Set:  (102448, 8) (102448,)
# Test Set:  (25613, 8) (25613,)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
rf_classifier.fit(X_train, y_train)

# Make predictions on the test set
y_pred = rf_classifier.predict(X_test)

# Evaluate the model
print(classification_report(y_test, y_pred))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)

# You can visualize the confusion matrix using seaborn if you want
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.60      0.63       775
#            1       0.84      0.89      0.86      6952
#            2       0.61      0.57      0.59       543
#            3       0.85      0.88      0.86      4904
#            4       0.42      0.31      0.36       108
#            5       0.67      0.51      0.58       957
#            6       0.45      0.33      0.38        69
#            7       0.65      0.49      0.56       650
#            8       0.63      0.57      0.60       605
#            9       0.82      0.85      0.83      4965
#           10       0.61      0.61      0.61       376
#           11       0.81      0.86      0.83      3402
#           12       0.42      0.33      0.37        75
#           13       0.69      0.49      0.57       692
#           14       0.52      0.24      0.33        67
#           15       0.64      0.50      0.56       473
#
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_test, rf_classifier.predict(X_test))*100)
# Out:
# 79.84617186584937

# %%
import pickle

# %%
pickle.dump(rf_classifier, open("personality.pkl",'wb'))
